# %% [raw]
# Q1. What is Statistics?
# statistics :  is the science of collecting, organizing and analyzing a data(helps in decision making process).
#
# Q2. Define the different types of statistics and give an example of when each type might be used?
#
# Descriptive Statistics :
#
# 1) It consists of organizing  and summarizing data.
#
# 2) Measure of central tendency (mean,median,mode)
#
# 3) Measure of Dispersion (variance, std)
#
# 4) Different type of distribution of data
# ex: histogram, pdf, pmf
#
# Inferential Statistics:
#
# 1) It consists of using data you have measured to form conclusion.
#
# 2) population and sample data
#
# 3) z-test, t-test, chi-square -- hypothesis testing, H0,H,Pvalue, significance value
#
# ex: lets say there are 20 statistics classes at your college
# and you have collected the heights of students in the class ,
# heights are recorded  [175cm, 180cm, 140cm, 140cm, 135cm, 160cm, 135cm, 190cm]
#
# descriptive question: what is the average height of entire collection:
#       ( 175 + 180 + 140 + 140 + 135 + 160 + 135 + 190 )/8
# inferential question : are the height of the students in classroom similar to what you expect in the entire college (entire college -- population) .. (students in classroom -- sample(subset of population)
#
# population and sample data
#
# population : the group you are interested in studying.
#
# sample : a subset of population
# ex: exit poll
#
#
# Q3. What are the different types of data and how do they differ from each other? Provide an example of
# each type of data?
#
# Types of Data:
#
# Dataset:
# DMC  DC   ISI  BUI  FWI  Classes   Region
# 3.4  7.8  1.4  8.9  0.7  not fire  0
# 4.1  6.9  1    3.9  0.4  fire      0
#
#                                       Data
#
#      Quantitative (Numerical Data)                 Qualitative (Categorical Data)
#      (+, -, %, * )
#
#  Discrete              continous                   Nominal               Ordinal
# (whole number         (any value                   ex: gender (M,F)      ex: customer feedback(good, bad, better)
#  ex: no. of            ex: weight,                     Blood Group & pincode
#  bank account              height,
#                            temperature,
#                            speed)
#  no. of
#  children in a
#  family)
#
#
#
#
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E
# (ii) Colour of mangoes: yellow, green, orange, red
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]
#
# i)   Qualitative : grades are categorical data ..
#
# ii)  Qualitative data .
#
# iii) Quantitative data : continous data (any value)
#
# iv)  Quantitative data : discrete (whole number)
#
#
#
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.
#
# Nominal: (data does not have ranking ex: Gender (Male , Female), Blood Group
#
# Ordinal : ranking based ex: Customer feedback (Good, bad, better).
#
# Interval: Data have consistent intervals between values but there's no true zero point. Example: Temperature in Celsius or Fahrenheit.
#
# Ratio: Data have consistent intervals between values and a true zero point, indicating absence of the quantity. Example: Height, weight.
#
# Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
# example to illustrate your answer.
#
# Understanding the level of measurement in data analysis is like using the right tool for the job. If you have a nominal variable, like colors, you wouldn't try to calculate an average because colors can't be added or subtracted. Similarly, if you have a ratio variable, like height in centimeters, you can calculate a meaningful average because zero represents the absence of height. It's about choosing the right analysis method for the type of data you have to get accurate results.
#
#
# Q7. How nominal data type is different from ordinal data type.
#
# Nominal: (data does not have ranking ex: Gender (Male , Female), Blood Group
#
# Ordinal : ranking based ex: Customer feedback (Good, bad, better).
#
#
# Q8. Which type of plot can be used to display data in terms of range?
# A histogram.
#
#
# Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
# type of statistics and explain how they are used.
#
#
# Descriptive Statistics :
#
# 1) It consists of organizing  and summarizing data.
#
# 2) Measure of central tendency (mean,median,mode)
#
# 3) Measure of Dispersion (variance, std)
#
# 4) Different type of distribution of data
# ex: histogram, pdf, pmf
#
# Inferential Statistics:
#
# 1) It consists of using data you have measured to form conclusion.
#
# 2) population and sample data
#
# 3) z-test, t-test, chi-square -- hypothesis testing, H0,H,Pvalue, significance value
#
# ex: lets say there are 20 statistics classes at your college
# and you have collected the heights of students in the class ,
# heights are recorded  [175cm, 180cm, 140cm, 140cm, 135cm, 160cm, 135cm, 190cm]
#
# descriptive question: what is the average height of entire collection:
#       ( 175 + 180 + 140 + 140 + 135 + 160 + 135 + 190 )/8
# inferential question : are the height of the students in classroom similar to what you expect in the entire college (entire college -- population) .. (students in classroom -- sample(subset of population)
#
# population and sample data
#
# population : the group you are interested in studying.
#
# sample : a subset of population
# ex: exit poll
#
#
# Q10. What are some common measures of central tendency and variability used in statistics? Explain
# how each measure can be used to describe a dataset?
#
# Common measures of central tendency include the mean, median, and mode. The mean is the average value of a dataset and provides a measure of the center. The median is the middle value when the dataset is ordered, and it is less affected by extreme values, making it useful for skewed distributions. The mode is the most frequently occurring value in the dataset.
#
# Measures of variability include the range, standard deviation, and variance. The range is the difference between the maximum and minimum values in the dataset and gives an indication of the spread of the data. The standard deviation measures the average distance of data points from the mean, providing information about the dispersion of the data. The variance is the average of the squared differences from the mean and is another measure of data spread. These measures help to understand how much the data values deviate from the central tendency, providing insights into the variability of the dataset.
